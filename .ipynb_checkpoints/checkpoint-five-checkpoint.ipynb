# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import numpy as np
import pandas as pd

# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

heart_df = pd.read_csv(r"C:\Users\nidhi\OneDrive\Desktop\LaunchCode-Project-HeartAttack\heart.csv")
heart_df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
# Import matplotlib and seaborn libraries to visualize the data

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Visualizing the data using heatmap
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(heart_df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
sns.pairplot(heart_df, x_vars='age', 
             y_vars='chol', height=4, aspect=1, kind='scatter')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.displot(heart_df.age, color="red", label="Age", kde= True)
plt.legend()

# %%
# Creating X and y
X = heart_df['age']
y = heart_df['chol']

# %%
# Splitting the variables 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
X_train
# Out:
# 3      56
# 162    41
# 112    64
# 278    58
# 209    59
#        ..
# 66     51
# 53     44
# 79     58
# 280    42
# 8      52
# Name: age, Length: 212, dtype: int64

# %%
y_train
# Out:
# 3      236
# 162    157
# 112    313
# 278    319
# 209    177
#       ...
# 66     222
# 53     141
# 79     240
# 280    315
# 8      199
# Name: chol, Length: 212, dtype: int64

# %%
# Importing Statsmodels.api library from Statsmodel package
import statsmodels.api as sm

# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %%
# Fitting the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# Printing the parameters
lr.params
# Out:
# const    196.701398
# age        0.922095
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   chol   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     6.569
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0111
# Time:                        23:49:41   Log-Likelihood:                -1117.0
# No. Observations:                 212   AIC:                             2238.
# Df Residuals:                     210   BIC:                             2245.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        196.7014     19.822      9.923      0.000     157.625     235.778
# ...

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)
plt.plot(X_train, 196.7013 + 0.9220*X_train, 'r')
plt.show()

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %%
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.030
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case. NO not effective in this case, Maybe it would be better to try some other Models.
#
# 3. Was your plot of the error terms a bell curve? Not really...
